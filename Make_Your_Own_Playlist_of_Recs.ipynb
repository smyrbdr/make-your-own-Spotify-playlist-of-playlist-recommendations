# %%
# Creates a playlist of #(playlist length)-recommended tracks per track in a playlist

# install Spotipy first
#!pip install Spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util


cid =' ' # Client ID; copy this from your app created on beta.developer.spotify.com
secret = ' ' # Client Secret; copy this from your app
username = ' ' # Your Spotify username

#for avaliable scopes see https://developer.spotify.com/web-api/using-scopes/
scope = 'user-library-read playlist-modify-public playlist-read-private'

redirect_uri=' '

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret) 

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

token = util.prompt_for_user_token(username, scope, cid, secret, redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)

# %%
#Create a dataframe of your playlist including tracks' names and audio features
import pandas as pd

sourcePlaylistID = '1fCOovfyVaAbUiPlqtRF09'
sourcePlaylist = sp.user_playlist(username, sourcePlaylistID);
tracks = sourcePlaylist["tracks"];
songs = tracks["items"];

track_ids = []
track_names = []

for i in range(0, len(songs)):
    if songs[i]['track']['id'] != None: # Removes the local tracks in your playlist if there is any
        track_ids.append(songs[i]['track']['id'])
        track_names.append(songs[i]['track']['name'])

features = []
for i in range(0,len(track_ids)):
    audio_features = sp.audio_features(track_ids[i])
    for track in audio_features:
        features.append(track)
        
playlist_df = pd.DataFrame(features, index = track_names)

# %%
playlist_df.head()
# Out:
#                                           acousticness  \
# The Bluest Blues (feat. George Harrison)        0.5180
# Bird of Paradise                                0.5960
# The Thrill Is Gone                              0.0934
# Times Makes Two                                 0.6430
# Riding the Blues                                0.5050
#
#                                                                                analysis_url  \
# The Bluest Blues (feat. George Harrison)  https://api.spotify.com/v1/audio-analysis/3d5e...
# Bird of Paradise                          https://api.spotify.com/v1/audio-analysis/0X7R...
# The Thrill Is Gone                        https://api.spotify.com/v1/audio-analysis/1xW9...
# Times Makes Two                           https://api.spotify.com/v1/audio-analysis/5LJF...
# Riding the Blues                          https://api.spotify.com/v1/audio-analysis/6r8w...
#
#                                           danceability  duration_ms  energy  \
# The Bluest Blues (feat. George Harrison)         0.404       447240   0.331
# Bird of Paradise                                 0.471       281467   0.437
# The Thrill Is Gone                               0.692       301133   0.493
# Times Makes Two                                  0.641       325987   0.537
# Riding the Blues                                 0.438       226987   0.432
#
#                                                               id  \
# The Bluest Blues (feat. George Harrison)  3d5e9kJDkgc7Jum8d8xtrl
# Bird of Paradise                          0X7RPlCMbifRgyg1RpsR0K
# The Thrill Is Gone                        1xW9HHRQe8MMGF8SBNgkBY
# Times Makes Two                           5LJFs3O1BFipvKh2wZHNMs
# Riding the Blues                          6r8w9NhDqcMY3l8SicsaDt
#
#                                           instrumentalness  key  liveness  \
# The Bluest Blues (feat. George Harrison)          0.353000    9    0.0786
# Bird of Paradise                                  0.641000    1    0.2780
# The Thrill Is Gone                                0.001660    9    0.1280
# Times Makes Two                                   0.000003   10    0.0528
# Riding the Blues                                  0.005210    4    0.1440
#
#                                           loudness  mode  speechiness  \
# The Bluest Blues (feat. George Harrison)   -11.487     0       0.0245
# Bird of Paradise                           -11.396     1       0.0370
# The Thrill Is Gone                          -9.662     0       0.0325
# Times Makes Two                             -6.921     0       0.0342
# Riding the Blues                            -7.931     0       0.0318
#
#                                             tempo  time_signature  \
# The Bluest Blues (feat. George Harrison)   73.904               4
# Bird of Paradise                          144.333               4
# The Thrill Is Gone                         86.644               4
# Times Makes Two                           112.085               4
# Riding the Blues                          127.104               4
#
#                                                                                  track_href  \
# The Bluest Blues (feat. George Harrison)  https://api.spotify.com/v1/tracks/3d5e9kJDkgc7...
# Bird of Paradise                          https://api.spotify.com/v1/tracks/0X7RPlCMbifR...
# The Thrill Is Gone                        https://api.spotify.com/v1/tracks/1xW9HHRQe8MM...
# Times Makes Two                           https://api.spotify.com/v1/tracks/5LJFs3O1BFip...
# Riding the Blues                          https://api.spotify.com/v1/tracks/6r8w9NhDqcMY...
#
#                                                     type  \
# The Bluest Blues (feat. George Harrison)  audio_features
# Bird of Paradise                          audio_features
# The Thrill Is Gone                        audio_features
# Times Makes Two                           audio_features
# Riding the Blues                          audio_features
#
#                                                                            uri  \
# The Bluest Blues (feat. George Harrison)  spotify:track:3d5e9kJDkgc7Jum8d8xtrl
# Bird of Paradise                          spotify:track:0X7RPlCMbifRgyg1RpsR0K
# The Thrill Is Gone                        spotify:track:1xW9HHRQe8MMGF8SBNgkBY
# Times Makes Two                           spotify:track:5LJFs3O1BFipvKh2wZHNMs
# Riding the Blues                          spotify:track:6r8w9NhDqcMY3l8SicsaDt
#
#                                           valence
# The Bluest Blues (feat. George Harrison)   0.2470
# Bird of Paradise                           0.3370
# The Thrill Is Gone                         0.2800
# Times Makes Two                            0.3260
# Riding the Blues                           0.0904

# %%
playlist_df=playlist_df[["id", "acousticness", "danceability", "duration_ms", 
                         "energy", "instrumentalness",  "key", "liveness",
                         "loudness", "mode", "speechiness", "tempo", "valence"]]
playlist_df.head()
# Out:
#                                                               id  \
# The Bluest Blues (feat. George Harrison)  3d5e9kJDkgc7Jum8d8xtrl
# Bird of Paradise                          0X7RPlCMbifRgyg1RpsR0K
# The Thrill Is Gone                        1xW9HHRQe8MMGF8SBNgkBY
# Times Makes Two                           5LJFs3O1BFipvKh2wZHNMs
# Riding the Blues                          6r8w9NhDqcMY3l8SicsaDt
#
#                                           acousticness  danceability  \
# The Bluest Blues (feat. George Harrison)        0.5180         0.404
# Bird of Paradise                                0.5960         0.471
# The Thrill Is Gone                              0.0934         0.692
# Times Makes Two                                 0.6430         0.641
# Riding the Blues                                0.5050         0.438
#
#                                           duration_ms  energy  \
# The Bluest Blues (feat. George Harrison)       447240   0.331
# Bird of Paradise                               281467   0.437
# The Thrill Is Gone                             301133   0.493
# Times Makes Two                                325987   0.537
# Riding the Blues                               226987   0.432
#
#                                           instrumentalness  key  liveness  \
# The Bluest Blues (feat. George Harrison)          0.353000    9    0.0786
# Bird of Paradise                                  0.641000    1    0.2780
# The Thrill Is Gone                                0.001660    9    0.1280
# Times Makes Two                                   0.000003   10    0.0528
# Riding the Blues                                  0.005210    4    0.1440
#
#                                           loudness  mode  speechiness  \
# The Bluest Blues (feat. George Harrison)   -11.487     0       0.0245
# Bird of Paradise                           -11.396     1       0.0370
# The Thrill Is Gone                          -9.662     0       0.0325
# Times Makes Two                             -6.921     0       0.0342
# Riding the Blues                            -7.931     0       0.0318
#
#                                             tempo  valence
# The Bluest Blues (feat. George Harrison)   73.904   0.2470
# Bird of Paradise                          144.333   0.3370
# The Thrill Is Gone                         86.644   0.2800
# Times Makes Two                           112.085   0.3260
# Riding the Blues                          127.104   0.0904

# %%
# Generate a new column for recommended tracks
# Set recommendation limit to the Playlist Length per track
# Check documentation for  recommendations; https://beta.developer.spotify.com/documentation/web-api/reference/browse/get-recommendations/

playlist_df['track_recs']=playlist_df['id'].apply(lambda x: [(track['id']) for track in 
                                                  sp.recommendations(seed_tracks=[x], limit=len(playlist_df))['tracks']])

# %%
# Take a look at recommended tracks for the first track

for track in sp.tracks(playlist_df['track_recs'][0])['tracks']:
    print(track['name'] + ' - ' + track['artists'][0]['name'] + ' - ' + track['external_urls']['spotify'])
# Out:
# Together 'Til The End Of Time - Al Kooper - https://open.spotify.com/track/5upnw7kWS9h52beiGbt2EU
# Berwick Road - Dave Hole - https://open.spotify.com/track/79dOjFAclyigoq1fzMVrxQ
# Smoked - Mark Selby - https://open.spotify.com/track/028laedZuCkNst2SKMdbDv
# Blues Medley - Live - Mike Bloomfield - https://open.spotify.com/track/1nyy7yku79STQ8srWmpnbH
# I'll Keep You Happy - Lonnie Mack - https://open.spotify.com/track/6RiYEXCZm4rpfGbM7by5aA
# Blues for Charlie - Popa Chubby - https://open.spotify.com/track/6RYPyHmXU2FDDgwBR9w17m
# Jim's Song - Ronnie Earl & The Broadcasters - https://open.spotify.com/track/1DeAlSgbdU6YJdLExKzMl7
# Love You So - Free - https://open.spotify.com/track/3f83sS29LSVbKBp1S0dE8t
# 59th Street Bridge Song (Feelin' Groovy) - Live - Mike Bloomfield - https://open.spotify.com/track/4cSKuBEITenAkFzf6w4GPZ
# Jet Set Jewel - Jack Bruce - https://open.spotify.com/track/6eH77Idlfbv9DZlpmxMCeo
# Flute Thing - Al Kooper - https://open.spotify.com/track/6nrMCRbjQGSMDLNt4j2L6j
# The Hard Way - Janiva Magness - https://open.spotify.com/track/5K4B4veRNbvnIoN2NT5x8r
# All That Makes Me Happy Is the Blues - Buddy Guy - https://open.spotify.com/track/7hsbxGPIEBr9G2wP9cTO2L
# Burnin' Bridges - Julian Sas - https://open.spotify.com/track/6t5po5GuYHbwwhzr6EmA4d
# The Bluest Blues - Alvin Lee - https://open.spotify.com/track/3H2LrcYZk56ahcsYvFCar1
# Marje's Melody - Ronnie Earl & The Broadcasters - https://open.spotify.com/track/3ZewawA5h2yP6RvhWlBdFq
# Oaxaca - Canned Heat - https://open.spotify.com/track/0owGJndFeK4dQxsGqz4beI
# Beautiful Child - Ronnie Earl - https://open.spotify.com/track/0E5vPocKVF9jhGX6r3mL15
# Going Going Gone - Al Kooper - https://open.spotify.com/track/35vWNek6LkAmbS4zG98Ejc
# Some Days - Mick Clarke - https://open.spotify.com/track/3Kzgf9eNU4rP4U2G0NylvV
# Sweet Miss Vee - Ronnie Earl & The Broadcasters - https://open.spotify.com/track/6OMq6hP7afS95EMxGtELQ4
# Good Ol' Dog - Bryce Janey - https://open.spotify.com/track/3IMAAjArcxnFHGtUDAIblv
# The Memory of Our Love - Henrik Freischlader - https://open.spotify.com/track/2jXrwWE32uQJBi50xCvE9c
# C-Boy's Blues - The Fabulous Thunderbirds - https://open.spotify.com/track/4Yc1LYGmKI7gyhCxmr4IEL
# Up All Night Thinking - Dave Hole - https://open.spotify.com/track/50K0keolkQdkxGs0owPPyY
# A Stern Warning - Leslie West - https://open.spotify.com/track/4jSkIrhS9SUjEjth63kPPU
# Precious Lord - Ronnie Earl & The Broadcasters - https://open.spotify.com/track/7shdA5dTeRHgMrRXRZXniG
# Riding the Blues - Snowy White - https://open.spotify.com/track/6r8w9NhDqcMY3l8SicsaDt
# Don't Throw Your Love On Me So Strong - Live - Mike Bloomfield - https://open.spotify.com/track/3RNolhWrqguexxU94YIGAG
# Pastorale - Ronnie Earl - https://open.spotify.com/track/3gOxx5bk0USBwj5q40rnYP
# Shrine - Jeff Beck - https://open.spotify.com/track/1oO27URDgEkXQNErdQsqUH

# %%
# Create a new playlist for track recommendations
playlist_recs = sp.user_playlist_create(username, 
                                        name='Recommended Songs for Playlist {}'.format(sourcePlaylist['name']))

# %%
# I would like to be sure the above function has a playlist description parameter, but it doesn't have.
import inspect
inspect.getargspec(sp.user_playlist_create)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   This is separate from the ipykernel package so we can avoid doing imports until
# ArgSpec(args=['self', 'user', 'name', 'public'], varargs=None, keywords=None, defaults=(True,))

# %%
# Add each track's recommends to the new playlist
for i in range(0,len(playlist_df)):
    sp.user_playlist_add_tracks(username, playlist_recs['id'], playlist_df['track_recs'].values[i])

# %%
# Check rec intersections of tracks
track_recs = playlist_df['track_recs'].tolist()
result = set(track_recs[0])
for s in track_recs[1:]:
    result.intersection_update(s)
print (result)
# Out:
# set()

# %%
# Change the playlist details
results = sp.user_playlist_change_details(
    username, playlist_recs['id'],
    description='Playlist of recommended tracks for each track in the source playlist - Created using Spotify web API and Spotipy')
print (results)
# doesn't work as expected unfortunately.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-dceae9c8ca4f> in <module>()
#       2 results = sp.user_playlist_change_details(
#       3     username, playlist_recs['id'],
# ----> 4     description='Playlist of recommended tracks for each track in the target playlist - Created using Spotify web API and Spotipy')
#       5 print (results)
#
# TypeError: user_playlist_change_details() got an unexpected keyword argument 'description'

# %%
inspect.getargspec(sp.user_playlist_change_details)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   """Entry point for launching an IPython kernel.
# ArgSpec(args=['self', 'user', 'playlist_id', 'name', 'public', 'collaborative'], varargs=None, keywords=None, defaults=(None, None, None))
